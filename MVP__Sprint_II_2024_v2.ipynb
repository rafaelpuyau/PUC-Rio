# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelpuyau/PUC-Rio/blob/main/MVP__Sprint_II_2024_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sprint II

# %% [markdown]
# ## Machine Learning e Analytics

# %% [markdown]
# **Aluno**: Rafael Mascarenhas Puyau
#
# **e-Mail**: puyau@proton.me
#
# **GitHub**: https://github.com/rafaelpuyau/

# %% [markdown]
# ### Alternativas

# %% [markdown]
# [ X ] Treinar modelos de machine learning para um problema de classificação ou regressão
#
# [ ] Treinar modelos de Deep Learning para um problema de visão computacional ou processamento de linguagem natural

# %% [markdown]
# ### Checklist

# %% [markdown]
# #### Definição do Problema

# %% [markdown]
# **Objetivo**: entender e descrever claramente o problema que está sendo resolvido

# %% [markdown]
# ##### Qual é a descrição do Problema?

# %% [markdown]
# O problema em questão reside na intersecção entre a vida moderna atribulada e as demandas incessantes por resultados, culminando em uma atmosfera de pressão constante. Dentro desse contexto, surge a necessidade premente de identificar se os indivíduos estão em risco de sofrer ataques cardíacos devido ao estresse desencadeado por essa turbulência cotidiana.
#
# Além disso, enfrentamos o desafio da sobrecarga informacional, onde somos inundados por um volume avassalador de dados, tornando-se crucial filtrar o que realmente agrega valor em meio a esse mar de informações.
#
# A preocupação com a saúde, incluindo hábitos alimentares e atividade física regular, muitas vezes é deixada em segundo plano diante das exigências do mundo moderno. Essa negligência pode resultar em consequências graves para a saúde a longo prazo.
#
# No entanto, à medida que avançamos, a tecnologia, especialmente o machine learning, emerge como uma ferramenta vital para nos auxiliar na busca por um equilíbrio saudável. Ela oferece a capacidade de analisar dados complexos, prever e extrair insights significativos, auxiliando os seres humanos na gestão do estresse, na adoção de hábitos saudáveis e na prevenção de doenças cardiovasculares.
#
# Assim, a descrição do problema abrange não apenas os desafios enfrentados na vida moderna, mas também as oportunidades oferecidas pela tecnologia para mitigar esses desafios e promover um estilo de vida mais equilibrado e saudável.

# %% [markdown]
# ##### Você tem premissas ou hipóteses sobre o problema? Quais?

# %% [markdown]
# **Premissas**:
#
# 1. <u>**Antecipação**</u>: Modelos de machine learning podem ser treinados para identificar padrões e sinais precoces que indicam um aumento no risco de um indivíduo sofrer um ataque cardíaco. Isso possibilita a antecipação de eventos adversos e a intervenção precoce.
#
# 2. <u>**Monitoramento regular**</u>: Com o uso de dispositivos de monitoramento de saúde conectados, o machine learning pode analisar dados contínuos sobre os sinais vitais de uma pessoa. Ele pode detectar alterações sutis e acompanhar a evolução do risco cardiovascular ao longo do tempo, permitindo ajustes nos cuidados preventivos conforme necessário.
#
# 3. <u>**Cuidados preventivos**</u>: Com base em algoritmos de machine learning, é possível desenvolver sistemas de recomendação personalizados para promover hábitos saudáveis e intervenções preventivas. Esses sistemas podem sugerir mudanças no estilo de vida, como dieta, exercícios e redução do estresse, com base nas características individuais e nos dados de monitoramento.
#
# 4. <u>**Maior poder computacional**</u>: O aumento do poder computacional permite o desenvolvimento e a execução de modelos de machine learning mais complexos, capazes de lidar com grandes volumes de dados de forma eficiente. Isso possibilita uma análise mais detalhada e precisa dos fatores de risco para doenças cardiovasculares, bem como a identificação de relações não lineares entre variáveis ​​que podem influenciar o risco cardiovascular.
#
# **Hipóteses**:
#
# 1. <u>**Hipótese 1**</u>: Um modelo de machine learning treinado com dados de saúde pode prever com precisão o risco individual de um ataque cardíaco com base em múltiplos fatores, incluindo histórico médico, estilo de vida e dados biométricos.
#
# 2. <u>**Hipótese 2**</u>: A implementação de um sistema de monitoramento contínuo de saúde, combinado com algoritmos de machine learning, pode reduzir significativamente o tempo entre a detecção de sinais de alerta e a intervenção médica, aumentando assim as chances de prevenção de eventos cardiovasculares graves.
#
# 3. <u>**Hipótese 3**</u>: Estratégias de intervenção preventiva baseadas em machine learning, como programas personalizados de mudança de estilo de vida, podem levar a uma redução do risco cardiovascular em populações de alto risco, resultando em benefícios de saúde a longo prazo e redução dos custos associados ao tratamento de doenças cardiovasculares.
#
# 4. <u>**Hipótese 4**</u>: Com o avanço do poder computacional, modelos de machine learning mais sofisticados podem ser desenvolvidos para identificar padrões complexos nos dados de saúde, levando a uma compreensão mais profunda dos mecanismos subjacentes às doenças cardiovasculares e ao desenvolvimento de novas estratégias de prevenção e tratamento.

# %% [markdown]
# ##### Que restrições ou condições foram impostas para selecionar os dados?

# %% [markdown]
# 1. <u>**Relevância do problema**</u>: A seleção dos dados foi guiada pela necessidade de abordar um problema recorrente na sociedade moderna, especificamente relacionado à saúde cardiovascular e à prevenção de mortes prematuras, como a que ocorreu com o meu pai aos 39 anos em 1991.
#
# 2. <u>**Fonte confiável**</u>: O conjunto de dados foi obtido no [**kaggle**](https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset), uma fonte reconhecida por disponibilizar conjuntos de dados de alta qualidade para projetos de machine learning. Isso garante a confiabilidade e a integridade dos dados utilizados na análise.
#
# 3. <u>**Conexão pessoal**</u>: A seleção dos dados também foi influenciada pelo conhecimento pessoal e pela memória afetiva do falecimento precoce do meu pai como já mencionado anteriormente. Essa conexão pessoal pode fornecer insights adicionais e motivação extra para a análise e a resolução do problema.
#
# Ao considerar as restrições e condições apresentadas acima, acredito que posso, através deste **MVP** garantir que os dados selecionados sejam relevantes, confiáveis ​​e motivadores, contribuindo assim para a criação de um modelo de classificação eficaz em machine learning e para a abordagem efetiva do problema de saúde cardiovascular na sociedade moderna num futuro próximo.

# %% [markdown]
# ##### Descreva seu dataset

# %% [markdown]
# O infarto do miocárdio, ou ataque cardíaco, é a morte das células de uma região do músculo do coração por conta da formação de um coágulo que interrompe o fluxo sanguíneo de forma súbita e intensa.
#
# Este dataset possui informações relevantes sobre os pacientes que deram entrada no hospital com este problema.
#
# * <u>**Atributos**</u> : São 14 atributos no total, sendo um deles o target
#   * **age**: age in years (idade em anos)
#     * valores: entre 29 e 77 anos
#   * **sex**:
#     * 0 = female
#     * 1 = male
#   * **cp**: tipo de dor no peito (chest pain type (4 values)):
#     * 0 = asymptomatic
#     * 1 = atypical angina
#     * 2 = non-anginal pain
#     * 3 = typical angina
#   * **trestbps**: pressão arterial em repouso (em mm Hg na admissão ao hospital)
#   (resting blood pressure (in mm Hg on admission to the hospital))
#     * valores: entre 94 e 200
#   * **chol**: colesterol sérico em mg/dl (serum cholestoral in mg/dl)
#     * valores: entre 126 e 564
#   * **fbs**: glicemia em jejum > 120 mg/dl (fasting blood sugar > 120 mg/dl)
#     * 0 = false
#     * 1 = true
#   * **restecg**: resultados eletrocardiográficos em repouso (resting electrocardiographic results):
#     * 0 = showing probable or definite left ventricular hypertrophy by Estes’ criteria
#     * 1 = normal
#     * 2 = having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#   * **thalach**: frequência cardíaca máxima alcançada (maximum heart rate achieved)
#     * valores: entre 71 e 202
#   * **exang**: angina induzida por exercício (exercise induced angina)
#     * 0 = no
#     * 1 = yes
#   * **oldpeak**: depressão do segmento ST induzida por exercício em relação ao repouso (ST depression induced by exercise relative to rest)
#     * valores: entre 0 e 6.2
#   * **slope**: a inclinação do pico do segmento ST do exercício (the slope of the peak exercise ST segment)
#     * 0 = downsloping
#     * 1 = flat
#     * 2 = upsloping
#   * **ca**: número de vasos principais coloridos por fluorosopia (number of major vessels colored by flourosopy)
#     * 0
#     * 1
#     * 2
#     * 3
#     * 4
#   * **thal**:
#     * 0 = no info
#     * 1 = fixed defect (no blood flow in some part of the heart)
#     * 2 = normal blood flow
#     * 3 = reversable defect (a blood flow is observed but it is not normal)
#   * **target**:
#     * 0 = no
#     * 1 = yes
#
#   **OBS**: Os nomes e números de segurança social dos pacientes foram recentemente removidos do banco de dados e substituídos por valores fictícios.
#
# * anotações
#   * quantidade de observações: 1025
#
# * demais informações relevantes
#   * Não há valores nulos

# %% [markdown]
# ##### Código

# %% [markdown]
# ###### Imports

# %%
# Configuração para não exibir os possível warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Imports necessários
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.patches as patches
from matplotlib import pyplot as plt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split # Faz a divisão da base em treino e teste
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Configura o estilo dos gráfico do Matplotlib
plt.style.use('dark_background')

# %%
# Formatação para evitar a apresentação de notação científica
pd.options.display.float_format = '{:20,.2f}'.format

# %% [markdown]
# ###### Carga do Dataset

# %%
# Informa a URL de importação do dataset
url = "https://raw.githubusercontent.com/rafaelpuyau/PUC-Rio/main/hearts.csv"

# Carga do data source
df = pd.read_csv(url)

# Apresenta as primeiras 5 linhas do dataset
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   52    1   0       125   212    0        1      168      0
# 1   53    1   0       140   203    1        0      155      1
# 2   70    1   0       145   174    0        1      125      1
# 3   61    1   0       148   203    0        1      161      0
# 4   62    0   0       138   294    1        1      106      0
#
#                oldpeak  slope  ca  thal  target
# 0                 1.00      2   2     3       0
# 1                 3.10      0   0     3       0
# 2                 2.60      0   0     3       0
# 3                 0.00      2   1     3       0
# 4                 1.90      1   3     2       0

# %%
# Verificar o número de observações e atributos
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# Coletando informações sobre o dataset:
#
#   * info
#   * describe
#   * valores nulos
#   * duplicated values

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# Através do método describe, pode-se observar que as colunas trestbps, chol e thalach possuem um elevado desvio padrão.
#
# Pode ser um indicativo de que precisamos realizam a padronização e normalização destas colunas para obter um melhor resultado do modelo

# %%
# Describe
df.describe()
# Out:
#                        age                  sex                   cp  \
# count             1,025.00             1,025.00             1,025.00
# mean                 54.43                 0.70                 0.94
# std                   9.07                 0.46                 1.03
# min                  29.00                 0.00                 0.00
# 25%                  48.00                 0.00                 0.00
# 50%                  56.00                 1.00                 1.00
# 75%                  61.00                 1.00                 2.00
# max                  77.00                 1.00                 3.00
#
#                   trestbps                 chol                  fbs  \
# count             1,025.00             1,025.00             1,025.00
# mean                131.61               246.00                 0.15
# std                  17.52                51.59                 0.36
# ...

# %% [markdown]
# Neste conjunto de dados há 723 observações duplicadas. Para que não tenha um problema no algoritmo gerando um vício no mesmo, essas observações duplicadas foram removidas.

# %%
# Verificação de valores nulos
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Duplicated values
df.duplicated().sum()
# Out:
# 723

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (302, 14)

# %% [markdown]
# O dataset não apresenta nenhum valor nulo, o que é muito bom! A qualidade de dados, para os modelos de **Machine Learning** é muito importante!
#
# Outro ponto a salientar é a redução do conjunto de dados (70,53%). O pouco número de observações poderá impactar o treinamento do modelo não deixando uma acurácia muito alta.
#
# No dia-a-dia, seria necessário buscar mais dados para melhorar a performance do modelo bem como sua acurácia.
#
# __VALE LEMBRAR__
#
# > "Entra lixo, sai lixo"

# %% [markdown]
# ###### Gráfcos exploratórios da conjunto de dados

# %%
# Deep copy
df_tmp = df.copy()

# %%
# Mudo os valores numéricos para variáveis categóricas
df_tmp["sex"] = df_tmp["sex"].apply(lambda valor: "Feminino" if valor == 0 else "Masculino")

# %%
# Mudo os valores numéricos para valores mais descritivos
df_tmp["target"] = df_tmp["target"].apply(
    lambda valor: "Tendência de Ataque do Coração" if valor == 1 else "Sem tendência de Atque do Coração")

# %%
# Mudo os valores numéricos para valores mais descritivos
# df_tmp["cp"] = df_tmp["cp"].apply(
#     lambda valor: "asymptomatic" if valor == 0 else "atypical angina" if valor == 1
#     else "non-anginal pain" if valor == 2 else "typical angina")

# %%
sns.countplot(data=df_tmp, x="sex", hue="target")
plt.title("\nTendência ou não de um ataque do coração\npor sexo\n");

# %%
sns.countplot(data=df_tmp, x="cp", hue="target")
plt.legend(title='Risco de Ataque Cardíaco', labels=['Menos chance', 'Mais chance'])
plt.title("\nTipo de dor no peito\n pela tendência de um ataque do coração\n");

# %% [markdown]
# Existem quatro tipos de dor no peito:
#
# 1. angina assintomática (valor 0 no dataset)
# 2. atípica (valor 1 no dataset)
# 3. dor não anginosa (valor 2 no dataset)
# 4. angina típica (valor 3 no dataset)
#
# A maioria dos pacientes com doenças cardíacas apresenta dor no peito assintomática. Esse grupo de pessoas pode apresentar sintomas atípicos, como indigestão, gripe ou distensão muscular no peito.
#
# Um ataque assintomático, como qualquer ataque cardíaco, envolve bloqueio do fluxo sanguíneo para o coração e possíveis danos ao músculo cardíaco. Os fatores de risco para ataques cardíacos assintomáticos são os mesmos daqueles com sintomas cardíacos. Esses fatores incluem:
#
#   * Idade
#   * Diabetes
#   * Excesso de peso
#   * História familiar de doença cardíaca
#   * Pressão alta
#   * Colesterol alto
#   * Falta de exercício
#   * Ataque cardíaco prévio
#   * Uso do tabaco

# %%
sns.countplot(data=df_tmp, x="sex",hue="thal")
plt.title("\nSexo por Talassemia\n");

# %% [markdown]
# A cardiomiopatia beta talassemia é caracterizada principalmente por dois fenótipos distintos, tipo dilatado, com dilatação ventricular esquerda e contratilidade prejudicada e um fenótipo restritivo, com sensação ventricular esquerda restritiva, hipertensão pulmonar e insuficiência cardíaca direita.
#
# Problemas cardíacos, insuficiência cardíaca congestiva e ritmos cardíacos anormais podem estar associados à talassemia grave.

# %%
sns.countplot(data=df_tmp, x="slope", hue="target")
plt.title("\nSlope por\n Tendência de um ataque do coração\n");

# %%
plt.figure(figsize=(16,5))
sns.distplot(df[df["target"] == 0]["age"], kde=False, bins=50)
plt.title("\nDistribuição por idade de pacientes\n que sofreram ataque do coração\n");

# %% [markdown]
# A doença cardíaca é muito comum em idosos, composta pela faixa etária de 60 anos ou mais, e comum entre adultos que pertencem à faixa etária de 41 a 60 anos. Mas é rara na faixa etária de 19 a 40 anos e muito rara na faixa etária de 0 a 18.

# %% [markdown]
# #### Preparação de Dados

# %% [markdown]
# **Objetivo**: realizar operações de preparação dos dados

# %% [markdown]
# Diante da diversidade de pacientes analisados e com características diferentes, apesar de alguns atributos apresentarem `outliers`, acredito que não sejam valores discrepantes dos demais e, sim, valores passíves de ocorrer nestes casos.
#
# Sendo assim, não removerei os "possíveis" `outliers`.

# %%
# Verificação de outliers
fig, ax = plt.subplots(nrows=2, ncols=7, figsize=(12,6))

fig.suptitle("Verificando outliers nos atributos", fontsize=16, fontweight="bold")

for pos, col in enumerate(df.columns[:-1]):
  line = pos // 7
  column = pos % 7
  ax[line, column].set_title(col)
  ax[line, column].boxplot(df[col])

plt.tight_layout()

# %% [markdown]
# ##### Refine a quantidade de atributos disponíveis, realizando o processo de _feature selection_ de forma adequada

# %%
# Feature Selection

# Realizo uma deep copy
data = df.copy()

# Colunas independentes
X = data.iloc[:,0:13]
# Coluna target
y = data.iloc[:,-1]

# Aplicação do SelectKBest para extrair/identificar as melhores features
bestfeatures = SelectKBest(score_func=chi2, k=10)
b_features = bestfeatures.fit(X,y)

# Criação do dataframe com os melhores scores
dfscores = pd.DataFrame(b_features.scores_)
# Criação do dataframe com o nome das colunas
dfcolumns = pd.DataFrame(X.columns)

# Junção dos dataframes para melhor visualização da pontuação
featureScores = pd.concat([dfcolumns,dfscores],axis="columns")

# Renomeando as colunas
featureScores.columns = ['Columns','Score']

# Mostra as maiores pontuações
featureScores.nlargest(12,'Score')
# Out:
#      Columns                Score
# 7    thalach               186.18
# 9    oldpeak                71.69
# 11        ca                71.02
# 2         cp                62.12
# 8      exang                38.52
# 0        age                22.21
# 4       chol                21.69
# 3   trestbps                15.09
# 10     slope                 9.68
# 1        sex                 7.72
# 12      thal                 5.75
# 6    restecg                 2.88

# %%
choosed_features = featureScores.nlargest(12, "Score").iloc[:8, 0].to_list()
choosed_features
# Out:
# ['thalach', 'oldpeak', 'ca', 'cp', 'exang', 'age', 'chol', 'trestbps']

# %% [markdown]
# O código acima mostra a significancia de cada coluna/feature para o futuro modelo. E com base nela, selecionarei as mais relevantes para o início do trabalho.
#
# As características escolhidas são:
#
#   * thalach
#   * oldpeak
#   * ca
#   * cp
#   * exang
#   * age
#   * chol
#   * trestbps

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap="magma",fmt='.2f');

# %%
'''
Este trecho de código fazia o filtro de outliers, porém, não o executei devido
ao número reduzido de observações no conjunto de dados
'''

# for key in df.columns.values.tolist():
#   Q1 = df[key].quantile(0.25)
#   Q3 = df[key].quantile(0.75)
#   IQR = Q3 - Q1 #IQR is interquartile range.

#   filter = (df[key] >= Q1 - 1.5 * IQR) & (df[key] <= Q3 + 1.5 *IQR)
#   df = df.loc[filter]
# Out:
# '\nEste trecho de código fazia o filtro de outliers, porém, não o executei devido\nao número reduzido de observações no conjunto de dados\n'

# %% [markdown]
# ##### Separe o dataset entre treino e teste (e validação, se aplicável)

# %%
# Esta variável define o tamanho do conjunto de teste. Neste caso, 20% do dataset original
test_set_size = 0.20

# Definição da semente aleatória para a reprodutibilidade do código
seed = 7

# Separação dos conjuntos de treino e teste
X = df[choosed_features] # df[df.columns[:-1]]
y = df[df.columns[-1]]

# Holdout com estratificação
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=test_set_size,
    shuffle=True,
    random_state=seed,
    stratify=y
)

# Parâmetros e participações da validação cruzada
scoring = "accuracy"
num_particoes = 10

# Validação cruzada com estratificação
kfold = StratifiedKFold(
    n_splits=num_particoes,
    shuffle=True,
    random_state=seed
)

# %%
# Modelagem e Inferência
np.random.seed(7) # definindo uma semente global

# Lista que armazenará os modelos
models = []

# Criando os modelos e adicionando-os na lista de modelos
models.append(('LR', LogisticRegression(max_iter=200)))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# Definindo os parâmetros do classificador base para o BaggingClassifier
base = DecisionTreeClassifier()
num_trees = 100
max_features = 3

# Criando os modelos para o VotingClassifier
bases = []
model1 = LogisticRegression(max_iter=200)
bases.append(('logistic', model1))
model2 = DecisionTreeClassifier()
bases.append(('cart', model2))
model3 = SVC()
bases.append(('svm', model3))

# Criando os ensembles e adicionando-os na lista de modelos
models.append(('Bagging', BaggingClassifier(base_estimator=base, n_estimators=num_trees)))
models.append(('RF', RandomForestClassifier(n_estimators=num_trees, max_features=max_features)))
models.append(('ET', ExtraTreesClassifier(n_estimators=num_trees, max_features=max_features)))
models.append(('Ada', AdaBoostClassifier(n_estimators=num_trees)))
models.append(('GB', GradientBoostingClassifier(n_estimators=num_trees)))
models.append(('Voting', VotingClassifier(bases)))

# Listas para armazenar os resultados
results = []
names = []

# Avaliação dos modelos
for name, model in models:
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    print(f"{name}: {cv_results.mean():.6f} ({cv_results.std():.6f})")

# Boxplot de comparação dos modelos
fig = plt.figure(figsize=(15,10))
fig.suptitle('Comparação dos Modelos')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.808667 (0.062945)
# KNN: 0.652000 (0.090477)
# CART: 0.767333 (0.075617)
# NB: 0.804833 (0.077221)
# SVM: 0.693167 (0.044419)
# Bagging: 0.809000 (0.062660)
# RF: 0.817333 (0.042799)
# ET: 0.833833 (0.064889)
# Ada: 0.742333 (0.072561)
# GB: 0.788000 (0.060977)
# Voting: 0.796500 (0.060683)

# %%
# Junto as listas de nomes e resultados
final_result = list(zip(names, [ round(val.mean(),6) for val in results ]))

# %%
# Ordeno para achar o modelo campeão
final_result.sort(key=lambda r: r[1], reverse=True)

# Plotagem dos gráficos dos resultados de cada modelo

# Extrair nomes dos modelos e pontuações
model_names = [result[0] for result in final_result]
scores = [result[1] for result in final_result]

# Plotagem dos gráficos dos resultados de cada modelo
fig, ax = plt.subplots(figsize=(15,4))

bars = ax.bar(model_names, scores, color=plt.cm.BuPu(scores))
ax.bar_label(bars, fmt=f"%.6f", padding=2)

plt.xlabel('Modelos')
plt.ylabel('Pontuações')
plt.title('Resultados dos Modelos')

plt.yticks([])

for border in ['top', 'right', 'left']:
  ax.spines[border].set_visible(False)

ax.spines['bottom'].set_linewidth(2.5)

plt.show()

# %%
# Criação e avaliação dos modelos : dados padronizados e normalizados
np.random.seed(7) # definindo uma semente global para este bloco

# Listas para armazenar os armazenar os pipelines e os resultados para todas as visões do dataset
pipelines = []
results = []
names = []

# Criando os elementos do pipeline

# Algoritmos que serão utilizados
reg_log = ('LR', LogisticRegression(max_iter=200))
knn = ('KNN', KNeighborsClassifier())
cart = ('CART', DecisionTreeClassifier())
naive_bayes = ('NB', GaussianNB())
svm = ('SVM', SVC())
bagging = ('Bag', BaggingClassifier(base_estimator=base, n_estimators=num_trees))
random_forest = ('RF', RandomForestClassifier(n_estimators=num_trees, max_features=max_features))
extra_trees = ('ET', ExtraTreesClassifier(n_estimators=num_trees, max_features=max_features))
adaboost = ('Ada', AdaBoostClassifier(n_estimators=num_trees))
gradient_boosting = ('GB', GradientBoostingClassifier(n_estimators=num_trees))
voting = ('Voting', VotingClassifier(bases))

# Transformações que serão utilizadas
standard_scaler = ('StandardScaler', StandardScaler())
min_max_scaler = ('MinMaxScaler', MinMaxScaler())


# Montando os pipelines

# Dataset original
pipelines.append(('LR-orig', Pipeline([reg_log])))
pipelines.append(('KNN-orig', Pipeline([knn])))
pipelines.append(('CART-orig', Pipeline([cart])))
pipelines.append(('NB-orig', Pipeline([naive_bayes])))
pipelines.append(('SVM-orig', Pipeline([svm])))
pipelines.append(('Bag-orig', Pipeline([bagging])))
pipelines.append(('RF-orig', Pipeline([random_forest])))
pipelines.append(('ET-orig', Pipeline([extra_trees])))
pipelines.append(('Ada-orig', Pipeline([adaboost])))
pipelines.append(('GB-orig', Pipeline([gradient_boosting])))
pipelines.append(('Vot-orig', Pipeline([voting])))

# Dataset Padronizado
pipelines.append(('LR-padr', Pipeline([standard_scaler, reg_log])))
pipelines.append(('KNN-padr', Pipeline([standard_scaler, knn])))
pipelines.append(('CART-padr', Pipeline([standard_scaler, cart])))
pipelines.append(('NB-padr', Pipeline([standard_scaler, naive_bayes])))
pipelines.append(('SVM-padr', Pipeline([standard_scaler, svm])))
pipelines.append(('Bag-padr', Pipeline([standard_scaler, bagging])))
pipelines.append(('RF-padr', Pipeline([standard_scaler, random_forest])))
pipelines.append(('ET-padr', Pipeline([standard_scaler, extra_trees])))
pipelines.append(('Ada-padr', Pipeline([standard_scaler, adaboost])))
pipelines.append(('GB-padr', Pipeline([standard_scaler, gradient_boosting])))
pipelines.append(('Vot-padr', Pipeline([standard_scaler, voting])))

# Dataset Normalizado
pipelines.append(('LR-norm', Pipeline([min_max_scaler, reg_log])))
pipelines.append(('KNN-norm', Pipeline([min_max_scaler, knn])))
pipelines.append(('CART-norm', Pipeline([min_max_scaler, cart])))
pipelines.append(('NB-norm', Pipeline([min_max_scaler, naive_bayes])))
pipelines.append(('SVM-norm', Pipeline([min_max_scaler, svm])))
pipelines.append(('Bag-norm', Pipeline([min_max_scaler, bagging])))
pipelines.append(('RF-norm', Pipeline([min_max_scaler, random_forest])))
pipelines.append(('ET-norm', Pipeline([min_max_scaler, extra_trees])))
pipelines.append(('Ada-norm', Pipeline([min_max_scaler, adaboost])))
pipelines.append(('GB-norm', Pipeline([min_max_scaler, gradient_boosting])))
pipelines.append(('Vot-norm', Pipeline([min_max_scaler, voting])))

# Executando os pipelines
for name, model in pipelines:
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    print(f"{name}: {cv_results.mean():.3f} ({cv_results.std():.3f})")

# Boxplot de comparação dos modelos
fig = plt.figure(figsize=(25,6))
fig.suptitle('Comparação dos Modelos - Dataset orginal, padronizado e normalizado')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names, rotation=90)
plt.show()
# Out:
# LR-orig: 0.809 (0.063)
# KNN-orig: 0.652 (0.090)
# CART-orig: 0.767 (0.076)
# NB-orig: 0.805 (0.077)
# SVM-orig: 0.693 (0.044)
# Bag-orig: 0.809 (0.063)
# RF-orig: 0.817 (0.043)
# ET-orig: 0.834 (0.065)
# Ada-orig: 0.742 (0.073)
# GB-orig: 0.788 (0.061)
# Vot-orig: 0.796 (0.061)
# LR-padr: 0.813 (0.063)
# KNN-padr: 0.780 (0.075)
# CART-padr: 0.755 (0.080)
# NB-padr: 0.805 (0.077)
# SVM-padr: 0.813 (0.090)
# Bag-padr: 0.813 (0.063)
# RF-padr: 0.805 (0.038)
# ET-padr: 0.821 (0.084)
# Ada-padr: 0.738 (0.071)
# GB-padr: 0.788 (0.061)
# Vot-padr: 0.813 (0.078)
# LR-norm: 0.817 (0.078)
# KNN-norm: 0.792 (0.088)
# CART-norm: 0.784 (0.075)
# NB-norm: 0.805 (0.077)
# SVM-norm: 0.809 (0.094)
# Bag-norm: 0.801 (0.075)
# RF-norm: 0.792 (0.053)
# ET-norm: 0.825 (0.089)
# Ada-norm: 0.742 (0.073)
# GB-norm: 0.792 (0.062)
# Vot-norm: 0.825 (0.097)

# %%
# Junto as listas de nomes e resultados depois de padronizados e normalizados
final_result = list(zip(names[-11:], [ round(val.mean(),6) for val in results[-11:] ]))

# %%
# Ordeno para achar o modelo campeão
final_result.sort(key=lambda r: r[1], reverse=True)

# Plotagem dos gráficos dos resultados de cada modelo

# Extrair nomes dos modelos e pontuações
model_names = [result[0] for result in final_result]
scores = [result[1] for result in final_result]

# Plotagem dos gráficos dos resultados de cada modelo
fig, ax = plt.subplots(figsize=(15,4))

bars = ax.bar(model_names, scores, color=plt.cm.BuPu(scores))
ax.bar_label(bars, fmt=f"%.6f", padding=2)

plt.xlabel('Modelos')
plt.ylabel('Pontuações')
plt.title('Resultados dos Modelos')

plt.yticks([])

for border in ['top', 'right', 'left']:
  ax.spines[border].set_visible(False)

ax.spines['bottom'].set_linewidth(2.5)

plt.show()

# %% [markdown]
# ##### Faz sentido utilizar um método de validação cruzada? Justifique se não utilizar

# %% [markdown]
# Como estudado, a validação cruzada é uma técnica fundamental em machine learning para avaliar o desempenho de um modelo em dados não vistos. Ela é usada em várias situações, incluindo:
#
# 1. **Avaliação do desempenho do modelo**: A validação cruzada fornece uma estimativa mais confiável do desempenho do modelo em dados não vistos do que simplesmente dividir os dados em conjuntos de treinamento e teste uma única vez. Isso ajuda a evitar a superestimação ou subestimação do desempenho do modelo.
#
# 2. **Seleção de modelos e hiperparâmetros**: Ao comparar diferentes algoritmos de aprendizado de máquina ou ajustar os hiperparâmetros de um modelo, a validação cruzada ajuda a escolher a melhor combinação que generalize bem para novos dados.
#
# 3. **Estimativa da variabilidade do modelo**: A validação cruzada fornece uma estimativa da variabilidade do desempenho do modelo em diferentes conjuntos de dados de treinamento e teste. Isso é útil para entender quão estável é o modelo e se ele é sensível às variações nos dados de treinamento.
#
# 4. **Prevenir overfitting**: A validação cruzada pode ajudar a identificar se um modelo está superajustando aos dados de treinamento. Se o desempenho do modelo for significativamente pior nos conjuntos de teste em comparação com os conjuntos de treinamento, pode ser um sinal de overfitting.
#
# 5. **Avaliação de desempenho em conjuntos de dados pequenos**: Em conjuntos de dados pequenos, como este por exemplo, dividir os dados em conjuntos de treinamento e teste pode levar a estimativas imprecisas do desempenho do modelo. A validação cruzada pode fornecer estimativas mais estáveis nessas situações.

# %% [markdown]
# ##### ~Verifique quais operações de transformação de dados (como normalização e padronização, transformação de imagens em tensores) são mais apropriadas para o seu problema e salve visões diferentes do seu dataset para posterior avaliação dos modelos~

# %% [markdown]
# #### Modelagem e Treinamento

# %% [markdown]
# **Objetivo**: construir modelos para resolver o problema em questão

# %% [markdown]
# ##### Selecione os algoritmos mais indicados para o problema e dataset escolhidos, justificando as suas escolhas

# %% [markdown]
# A seleção de modelos é uma etapa crítica no processo de aprendizado de máquina e ciência de dados. Ela envolve escolher o algoritmo mais adequado que se ajusta aos seus dados e ao problema em questão.
#
# Escolher o modelo correto pode ajudar a produzir previsões mais precisas e insights mais profundos a partir dos dados.
#
# Além disso ajuda a economizar tempo e recursos computacionais, permitindo focar em outros aspectos importantes do projeto.

# %% [markdown]
# Com base na exposição anterior, o modelo escolhido foi o **ExtraTrees** por ter apresentado um melhor desempenho geral.

# %% [markdown]
# ##### ~Há algum ajuste inicial para os hiperparâmetros?~

# %% [markdown]
# ##### O modelo foi devidamente treinado? Foi observado problema de underfitting?

# %% [markdown]
# Sim, diante dos dados que tenho, o modelo foi treinado corretamente. Não foram observador `overfitting` e nem `underfitting`

# %% [markdown]
# ##### É possível otimizar os hiperparâmetros de algum dos modelos? Se sim, faça-o, justificando todas as escolhas

# %% [markdown]
# **Tuning da Extra Tree**
#
# Os hiperparâmetros de uma Extra Tree, ou ExtraTreesClassifier/ExtraTreesRegressor em scikit-learn, são semelhantes aos de uma árvore de decisão tradicional, mas com algumas diferenças. Aqui estão os principais hiperparâmetros da Extra Tree:
#
# * n_estimators: Número de árvores na floresta.
#
# * criterion: Critério para avaliar a qualidade de uma divisão. Pode ser "gini" para o índice de Gini ou "entropy" para o ganho de informação.
#
# * max_depth: A profundidade máxima das árvores.
#
# * min_samples_split: O número mínimo de amostras necessárias para dividir um nó interno.
#
# * min_samples_leaf: O número mínimo de amostras necessárias em uma folha.
#
# * max_features: O número de features a considerar ao procurar a melhor divisão.
#
# * max_leaf_nodes: O número máximo de folhas que a árvore pode ter.
#
# * min_impurity_decrease: Um nó será dividido se a divisão diminuir a impureza em um valor maior ou igual a este.
#
# * bootstrap: Se amostras de bootstrap devem ser usadas ao construir árvores.
#
# * random_state: Semente para a geração de números aleatórios para reproduzibilidade.
#
# * n_jobs: O número de trabalhos em paralelo para executar durante o ajuste e a previsão. (-1 usa todos os processadores disponíveis).
#
# * class_weight: Peso associado a cada classe na forma de um dicionário.

# %%
# Tuning do ET

np.random.seed(7) # definindo uma semente global para este bloco

pipelines = []

# Definindo os componentes do pipeline
et = ('ET', ExtraTreesClassifier())
standard_scaler = ('StandardScaler', StandardScaler())
min_max_scaler = ('MinMaxScaler', MinMaxScaler())

pipelines.append(('et-orig', Pipeline(steps=[et])))
pipelines.append(('et-padr', Pipeline(steps=[standard_scaler, et])))
pipelines.append(('et-norm', Pipeline(steps=[min_max_scaler, et])))

param_grid = {
    "ET__n_estimators": [tree for tree in range(100,400,100)],
    "ET__max_features": [feature for feature in range(1,11)],
    # "ET__criterion": ["gini", "entropy"],
    "ET__max_depth": [d for d in range(1,11)]
}

# Prepara e executa o GridSearchCV
for name, model in pipelines:
    grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
    grid.fit(X_train, y_train)
    # imprime a melhor configuração
    print("Sem tratamento de missings: %s - Melhor: %f usando %s" % (name, grid.best_score_, grid.best_params_))
# Out:
# Sem tratamento de missings: et-orig - Melhor: 0.838167 usando {'ET__max_depth': 9, 'ET__max_features': 4, 'ET__n_estimators': 200}
# Sem tratamento de missings: et-padr - Melhor: 0.838167 usando {'ET__max_depth': 10, 'ET__max_features': 5, 'ET__n_estimators': 200}
# Sem tratamento de missings: et-norm - Melhor: 0.846500 usando {'ET__max_depth': 9, 'ET__max_features': 7, 'ET__n_estimators': 200}

# %% [markdown]
# ##### Há algum método avançado ou mais complexo que possa ser avaliado?

# %% [markdown]
# No momento não.

# %% [markdown]
# ##### ~Posso criar um cômite de modelos diferentes para o problema (ensembles)?~

# %% [markdown]
# #### Avaliação de Resultados

# %% [markdown]
# **Objetivo**: analisar o desempenho dos modelos gerados em dados não vistos (com a base de teste)

# %% [markdown]
# ##### Selecione as métricas de avaliação condizentes com o problema, justificando

# %%
'''
Testei estes valores, mas acabei usando o que o GridSearch me retornou
Max Features = 2
Nº estimators = 200
Acurácia de 0.8032786885245902
-- X --
Criterion = "gini"
Max Features = 6
Nº estimators = 300
Max Depth = 4
Acurácia de 0.8360655737704918
'''

np.random.seed(7)

# Avaliação do modelo com o conjunto de testes

# Preparação do modelo
scaler = StandardScaler().fit(X_train) # ajuste do scaler com o conjunto de treino
rescaledX = scaler.transform(X_train) # aplicação da padronização no conjunto de treino
model = ExtraTreesClassifier(criterion="gini", max_features=6, n_estimators=300, max_depth=4)
model.fit(rescaledX, y_train)

# Estimativa da acurácia no conjunto de teste
rescaledTestX = scaler.transform(X_test) # aplicação da padronização no conjunto de teste
predictions = model.predict(rescaledTestX)
print(accuracy_score(y_test, predictions))
# Out:
# 0.8360655737704918

# %%
# Gráfico que mostra o critério

tree_range = range(1,11)
scores = {}

for _tree in tree_range:
  dtET = ExtraTreesClassifier(criterion="entropy", random_state=7, max_depth=_tree)
  dtET.fit(rescaledX, y_train)
  predictions = dtET.predict(rescaledTestX)
  scores[_tree] = accuracy_score(y_test,predictions)
plt.plot(tree_range, list(scores.values()), label="entropy", marker="o")

for _tree in tree_range:
  dtET = ExtraTreesClassifier(criterion="gini", random_state=7, max_depth=_tree)
  dtET.fit(rescaledX, y_train)
  predictions = dtET.predict(rescaledTestX)
  scores[_tree] = accuracy_score(y_test,predictions)
plt.plot(tree_range, list(scores.values()), label="gini", marker="o")

plt.xlabel("Profundidade da Árvore")
plt.ylabel("% de Acurácia")

plt.xticks(tree_range)
plt.title("\nAnálise\nProfundidade da Árvore X Acurácia\n")
plt.legend()
plt.show()

# %%
# Matriz de Confusão
et_conf_matrix = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=et_conf_matrix, display_labels=y_train.unique())
disp.plot();

# %% [markdown]
# ##### Treine o modelo escolhido com toda a base de treino e teste-o com a base de teste

# %%
# Preparação do modelo com TODO o dataset
scaler = StandardScaler().fit(X) # ajuste do scaler com TODO o dataset
rescaledX = scaler.transform(X) # aplicação da padronização com TODO o dataset
model.fit(rescaledX, y)
# Out:
# ExtraTreesClassifier(max_depth=4, max_features=6, n_estimators=300)

# %% [markdown]
# __VALE LEMBRAR__: No meu GitHub, você encontrará o arquivo arvores.svg, que é a imagem abaixo. Isso permitirá que o professor abra no navegador ou em um programa compatível para ampliar e visualizar seu conteúdo.

# %%
# Impressão da Árvore
n_trees = 1
fig, axes = plt.subplots(nrows=1, ncols=n_trees, figsize=(20, 10), dpi=300)
for index in range(n_trees):
    tree.plot_tree(model.estimators_[index], ax=axes, feature_names= df.columns.values.tolist())
plt.savefig("arvores.svg", dpi=300)
plt.show()

# %%
# Novos dados
data = {
  "age": [48, 46, 27, 13],
  "sex": [1, 0, 0, 0],
  "cp": [0, 1, 1, 2],
  "trestbps": [125, 140, 145, 148],
  "chol": [300, 250, 170, 150],
  "fbs": [1, 0, 0, 0],
  "restecg": [0, 1, 1, 1],
  "thalach": [185, 170, 160, 150],
  "exang": [1, 0, 0, 1],
  "oldpeak": [1.00, 3.10, 2.60, 0.00],
  "slope": [2, 0, 1, 1],
  "ca": [2, 0, 0, 1],
  "thal": [1, 2, 2, 2]
}

atributos = ["thalach", "oldpeak", "ca", "cp", "exang", "age", "chol", "trestbps", "sex", "fbs", "restecg", "slope", "thal"]
entrada = pd.DataFrame(data, columns=atributos)

array_entrada = entrada.values
X_entrada = array_entrada[:, 0:8].astype(float)

# Padronização nos dados de entrada usando o scaler utilizado em X
rescaledEntradaX = scaler.transform(X_entrada)
print(rescaledEntradaX)
# Out:
# [[ 1.54951109 -0.03712404  1.27497996 -0.93520799  1.43195847 -0.71078778
#    1.0354625  -0.37655636]
#  [ 0.89350312  1.77395808 -0.71491124  0.0353515  -0.69834428 -0.93219872
#    0.06774054  0.47891019]
#  [ 0.45616448  1.34274805 -0.71491124  0.0353515  -0.69834428 -3.03560267
#   -1.4806146   0.76406571]
#  [ 0.01882584 -0.8995441   0.28003436  1.005911    1.43195847 -4.58547926
#   -1.86770339  0.93515902]]

# %%
# Predição de classes dos dados de entrada
saidas = model.predict(rescaledEntradaX)
print(saidas)
# Out:
# [0 1 1 1]

# %% [markdown]
# ##### Os resultados fazem sentido?

# %% [markdown]
# No meu entendimento sim. Claro que com um volume maior de dados, poderei melhorar o treinamento do meu modelo bem como seu desempenho em dados não vistos.

# %% [markdown]
# ##### Foi observado algum problema de overfitting?

# %% [markdown]
# Respondido numa seção acima.

# %% [markdown]
# ##### ~Compare os resultados de diferentes modelos~

# %% [markdown]
# ##### Descreva a melhor solução encontrada, justificando

# %% [markdown]
# Nas etapas anteriores, conduzi a seleção de características com base na significância de cada atributo, identificando 8 dos 13 como os mais relevantes e adequados para o modelo em questão.
#
# Posteriormente, busquei otimizar os hiperparâmetros do modelo selecionado, porém não observei mudanças significativas em seu desempenho. Essa estagnação pode ser atribuída ao tamanho limitado do conjunto de dados. Embora os resultados obtidos sejam os melhores possíveis com base nas informações disponíveis, estou convicto de que o código está bem estruturado para adaptar-se e aprimorar-se quando mais observações estiverem disponíveis.

# %% [markdown]
# ### Conclusão

# %% [markdown]
# Escreva aqui a conclusão do trabalho

# %% [markdown]
# Em conclusão, este trabalho de análise de um conjunto de dados sobre ataques cardíacos revelou insights valiosos e desafios interessantes para abordagens futuras em machine learning:
#
# 1. Apesar do conjunto de dados limitado, o modelo desenvolvido demonstrou uma acurácia regular. No entanto, para uma avaliação mais abrangente, futuras iterações devem incluir métricas como Precisão e Recall, oferecendo uma visão mais completa do desempenho do modelo.
#
# 2. Durante a análise exploratória, ficou evidente que os homens têm uma tendência maior a sofrerem riscos de infarto em comparação com as mulheres. Explorar mais essa disparidade de gênero pode oferecer insights valiosos para estratégias de prevenção e tratamento.
#
# 3. A presença de dor no peito emergiu como um indicador claro de risco de ataque cardíaco, indicando a importância de uma avaliação cuidadosa por parte dos cardiologistas. Além disso, os níveis de colesterol desempenham um papel crucial nesse risco, destacando a necessidade de monitoramento regular e intervenções preventivas.
#
# 4. O gráfico de distribuição por idade dos pacientes afetados por ataques cardíacos destacou claramente as faixas etárias mais vulneráveis, oferecendo informações valiosas para aprimorar os cuidados e a vigilância desses pacientes.
#
# 5. No desenvolvimento do código, técnicas como _feature selection_ foram empregadas para identificar os atributos mais relevantes, enquanto a _validação cruzada_ foi utilizada para melhorar o desempenho do modelo, apesar do conjunto de dados limitado. Essas abordagens ajudaram a otimizar o modelo e destacaram a importância da qualidade dos dados e da seleção de características.
#
# Por fim, gostaria de expressar minha gratidão à **PUC-Rio** pelo compartilhamento do conhecimento e pela oportunidade de realizar este trabalho.
#
# Esta colaboração serve como motivação para aprimorar o modelo apresentado e continuar explorando novas soluções para resolver uma variedade de problemas em diferentes setores da economia e da vida.
